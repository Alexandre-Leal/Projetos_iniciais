# %% [markdown]
# ## Estatistica dos jogadores no 1 Split de 2021

# %%
import pandas as pd

# %%
df = pd.read_html('https://lol.fandom.com/wiki/Special:RunQuery/TournamentStatistics?TS%5Btournament%5D=CBLOL%2F2021+Season%2FSplit+1&TS%5Bpreload%5D=TournamentByPlayer&pfRunQueryFormName=TournamentStatistics#pfForm')

# %%
for a in df:
    print(a)
# Out:
#    Tournament: CBLOL/2021 Season/Split 1 - Showing Values Per Game  \
#              Player Statistics - 90 Total Games Played, 65 Players
#         Restrict By Role (Query Permalinks):TopJungleMidBotSupport
# 0                Restrict By Role (Query Permalinks):
# 1                                                 NaN
# 2                                                  ⁠⁠
# 3                                                  ⁠⁠
# 4                                                  ⁠⁠
# ..                                                ...
# 62                                                 ⁠⁠
# 63                                                 ⁠⁠
# 64                                                 ⁠⁠
# 65                                                 ⁠⁠
# 66                                                 ⁠⁠
#
#                                                                  \
#
#    Restrict By Role (Query Permalinks):TopJungleMidBotSupport.1
# ...
